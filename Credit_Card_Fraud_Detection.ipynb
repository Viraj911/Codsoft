# %%
import os
import warnings
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the given dataset about credit card

# %%
df = pd.read_csv('creditcard.csv')
df1 = df.copy(deep = True)
df2 = df.copy(deep = True)

# %%
df1.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # Analyse information from data

# %%
df1.shape
# Out:
# (284807, 31)

# %% [markdown]
# # Describe the data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # Check the null value

# %%
df1.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # Divide the data numerical and categorical wise for univariate analysis

# %%
num = df1.select_dtypes(include = 'number')
cat = df1.select_dtypes(include = 'object')

# %% [markdown]
# # Distribution analysis

# %%
for i in num:
  sns.distplot(df1[i], kde = True, color = 'green')
  plt.show()

# %%
df1[df1.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %% [markdown]
# # Check and Remove Duplicate Rows data

# %%
df1.drop_duplicates(keep = 'first', inplace = True)

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Time, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
df1.shape
# Out:
# (283726, 31)

# %% [markdown]
# # distribution of legit transactions & fraudulent transactions

# %%
df1['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %% [markdown]
# # separating the data for analysis

# %%
legit = df1[df1.Class == 0]
fraud = df1[df1.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (283253, 31)
# (473, 31)

# %% [markdown]
# # statistical measures of the data

# %%
legit.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# # compare the values for both transactions

# %%
df1.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %% [markdown]
# # Under-Sampling
#
# This Dataset is highly unblanced
#
# 0 --> Normal Transaction
#
# 1 --> fraudulent transaction
#
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 473

# %%
legit_sample = legit.sample(n=473)

# %% [markdown]
# # Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 183458  125807.0  2.067473  0.137676 -1.666600  0.445016  0.336155 -0.947921
# 266473  162344.0 -1.916833 -1.771921  1.302112 -0.411147  1.582999 -0.989941
# 139376   83124.0 -0.629595  1.018650  1.739697  0.099560 -0.332683 -1.236753
# 194099  130442.0 -0.541184  1.359935  0.567559  3.583496  0.521251  0.706307
# 88106    61989.0 -1.846258  0.966572  0.585644  0.869711  0.201373 -0.630277
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 183458  0.165820 -0.224773  0.536023  ... -0.361560 -0.952249  0.356409
# 266473 -0.414383  0.304305 -0.017083  ...  0.080499 -0.594525  0.666955
# 139376  0.667819 -0.115379 -0.303233  ... -0.185475 -0.519866  0.125856
# 194099  0.369288  0.681648 -1.547478  ...  0.231295  0.672182 -0.251240
# 88106   0.289823  0.209569  0.215253  ...  0.008153  0.450599 -0.126361
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96024.995772 -0.016221  0.132518 -0.090793 -0.050473  0.054136
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.032645 -0.008883  0.056547  0.043880  ... -0.028291  0.042523
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.466550
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.029524 -0.010621  0.015043 -0.002505 -0.009345 -0.018259  0.008007
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       74.113911
# 1      123.871860
#
# [2 rows x 30 columns]

# %% [markdown]
# # Create the target data and feature data where target data

# %%
x = new_dataset.drop(['Class'], axis = 1)
y = new_dataset['Class']

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.2, random_state = 69, stratify = y)

# %% [markdown]
# # Apply Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_x)
train_x1 = pd.DataFrame(scaler.transform(train_x), columns = train_x.columns)
test_x1 = pd.DataFrame(scaler.transform(test_x), columns = test_x.columns)

# %%
train_x1
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0    0.406844  0.910621  0.299249  0.947234  0.222807  0.687034  0.510045
# 1    0.106717  0.449502  0.521160  0.342247  0.939800  0.450899  0.332702
# 2    0.753337  0.991625  0.265732  0.824238  0.182316  0.737638  0.742967
# 3    0.395731  0.517999  0.695608  0.612924  0.442218  0.514777  0.944563
# 4    0.344240  0.690806  0.046807  0.845270  0.448333  0.797430  0.102936
# ..        ...       ...       ...       ...       ...       ...       ...
# 751  0.545435  0.718017  0.452056  0.608532  0.806541  0.418108  0.321611
# 752  0.964869  0.992014  0.275596  0.868110  0.255217  0.659610  0.390270
# 753  0.194396  0.965159  0.274749  0.917432  0.228088  0.650910  0.474611
# 754  0.217602  0.918295  0.278726  0.903577  0.070961  0.643854  0.412649
# 755  0.751347  0.985390  0.252027  0.942054  0.384006  0.615645  0.566849
#
#            V7        V8        V9  ...       V20       V21       V22  \
# ...

# %% [markdown]
# #  Create a DecisionTree model and Random Forest model for Target and feature data

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
model1 = DecisionTreeClassifier()
model2 = RandomForestClassifier()

# %% [markdown]
# # Overall Evaluation

# %%
model1.fit(train_x1, train_y)
pred1 = model1.predict(test_x1)

c_matrix1 = confusion_matrix(test_y, pred1)
acc1 = accuracy_score(test_y, pred1)

print('confusion matrix is: \n', c_matrix1, '\n', 'and accuracy is: \n', acc1)
print('Precision score is: \n',precision_score(test_y,pred1))
print('recall_score is: \n',recall_score(test_y,pred1))
print('f1_score is: \n',f1_score(test_y,pred1))
print("result",np.mean(cross_val_score(model1,x,y,scoring='accuracy',cv=10)))
# Out:
# confusion matrix is:
#  [[84 11]
#  [ 4 91]]
#  and accuracy is:
#  0.9210526315789473
# Precision score is:
#  0.8921568627450981
# recall_score is:
#  0.9578947368421052
# f1_score is:
#  0.9238578680203046
# result 0.8985666293393058

# %%
model2.fit(train_x1, train_y)
pred2 = model2.predict(test_x1)

c_matrix2 = confusion_matrix(test_y, pred2)
acc2 = accuracy_score(test_y, pred2)

print('confusion matrix is: \n', c_matrix2, '\n', 'and accuracy is: \n', acc2)
print('Precision score is: \n',precision_score(test_y,pred2))
print('recall_score is: \n',recall_score(test_y,pred2))
print('f1_score is: \n',f1_score(test_y,pred2))
print("result",np.mean(cross_val_score(model2,x,y,scoring='accuracy',cv=10)))
# Out:
# confusion matrix is:
#  [[91  4]
#  [ 8 87]]
#  and accuracy is:
#  0.9368421052631579
# Precision score is:
#  0.9560439560439561
# recall_score is:
#  0.9157894736842105
# f1_score is:
#  0.935483870967742
# result 0.9439753639417694
